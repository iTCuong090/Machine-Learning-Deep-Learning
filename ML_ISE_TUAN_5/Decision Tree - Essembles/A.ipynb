# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ý 1:
#
# Bài toán phân loại nhị phân, xét node gốc ta cần tính Entropy của nhãn cần dự đoán. Ta đếm số lượng nhãn Cat(1) là: 5, tổng số lượng mẫu có nhãn là: 10. Vì vậy xác suất p của nhãn Cat(1) là: 1/2.
#
# Thay vào công thức tính Entropy: H(p)=-p*log2(p)-(1-p)log2(1-p).
# Suy ra H(root)=1 (Entropy cao nhất, hỗn loạn nhất).
#
# Ý 2:
#
# Nếu split tại root theo Ear shape:
#
# Xác suất để Cat mang ear shape Pointy là: p=4/5 => Entropy của node Pointy là: H(Pointy) = -4/5*log2(4/5)-1/5log2(1/5) = 0.722 .
#
# Xác suất để Cat mang ear shape Floppy là: p=1/5 => Entropy của node Floppy là: H(Floppy) = thay số công thức = 0.722 .
#
# Vì số mẫu mang feature Pointy và Floppy bằng nhau và bằng 5. => Tổng trọng số Entropy nếu chia split theo Ear Shape là: H(Ear)=5/10*0.722+5/10*0.722 = 0.722.
#
# => Information gain IG(Ear) = H(Root)-H(Ear) = 0.278.
#
# Nếu split tại root theo Face shape:
#
# Xác suất để cat mang face shape Round là: p=4/7 => Entropy của node Round là: H(round) = 0.985.
#
# Xác suất để cat mang face shape not round là: p=1/3 => Entropy của node not round là: H(not round) = 0.918
#
# => Entropy tổng nếu split theo Face shape là: H(Face shape) = 7/10*0.985+3/10*0.918 = 0.965
#
# => IG(Face shape) = 1 - 0.965 = 0.035.
#
# Nếu split tại root theo Wiskers:
#
# Xác suất để Cat có wiskers present là: p=3/4 => Entropy của node Present: H(present) = 0.811.
#
# Xác suất để Cat có wiskers absent là: p=2/6 => Entropy của node absent: H(Absent) = 0.918.
#
# => Entropy tổng nếu split theo Wiskers là: H(wisker) = 4/10*0.811 + 2/6*0.918 = 0.875
#
# => IG(Wisker) = 1-0.875 = 0.125.
#
# TỔNG KẾT: So sánh các IG từ việc lựa chọn các feature để split: 0.278, 0.035, 0.125.
#
# Ý 3:
#
# => Split theo Ear shape mang lại nhiều thông tin nhất (IG=0.278) => Từ root ta chọn split theo Ear shape!.
